# %%
# https://docs.openmicroscopy.org/omero/5.6.0/developers/Python.html

# %%
#!pip install omero-py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 33.0 MB/s eta 0:00:00m eta 0:00:010:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 45.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for zeroc-ice: filename=zeroc_ice-3.6.5-cp38-cp38-linux_x86_64.whl size=24113730 sha256=9a071a067aa1de33cbe58f57e4520a5d357a372bb7dd2c0edbb7619cd9358ac4
#   Stored in directory: /home/uwamichi/.cache/pip/wheels/d5/18/29/d9699d2bd9f28ea3f7e0ec3d263dc8e05e959f4ca6b4e4a19b
# Successfully built zeroc-ice
# ...

# %%
import omero.clients
from omero.gateway import BlitzGateway
from omero.gateway.scripts import dbhelpers

from getpass import getpass

# %%
help(BlitzGateway)
# Out:
# Help on class _BlitzGateway in module omero.gateway:
#
# class _BlitzGateway(builtins.object)
#  |  _BlitzGateway(username=None, passwd=None, client_obj=None, group=None, clone=False, try_super=False, host=None, port=None, extra_config=None, secure=False, anonymous=True, useragent=None, userip=None)
#  |
#  |  Connection wrapper. Handles connecting and keeping the session alive,
#  |  creation of various services, context switching, security privileges etc.
#  |
#  |  Methods defined here:
#  |
#  |  __enter__(self)
#  |      Enter a context manager, connect if necesaary
#  |      Raise Exception if not connected
#  |
#  |      with BlitzGateway('user', 'password', host='host') as conn:
#  |          print list(conn.getObjects('Project'))
#  |
#  |  __exit__(self, *args)
#  |      Exit a context manager, close connection
#  |
# ...

# %%
path_omero_login_info = '../omero_uwamichi'

with open(path_omero_login_info) as f:
    host = f.readline().replace('\n', '')
    username = f.readline().replace('\n', '')

#client = omero.client(host=host)
#session = client.createSession(username=username, password=getpass("OMERO Password: "))
#conn = BlitzGateway(client_obj=client, secure = True)
conn = BlitzGateway(host=host,
                    username=username,
                    passwd=getpass("OMERO Password: "), secure=True)

conn.connect()
# Out:
# OMERO Password: ········
# True

# %%
conn

# %%
help(dbhelpers.ProjectEntry)
# Out:
# Help on class ProjectEntry in module omero.gateway.scripts.dbhelpers:
#
# class ProjectEntry(ObjectEntry)
#  |  ProjectEntry(name, owner, create_group=False, group_perms=None)
#  |
#  |  Method resolution order:
#  |      ProjectEntry
#  |      ObjectEntry
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, name, owner, create_group=False, group_perms=None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  create(self, client=None)
#  |
#  |  get(self, client=None, fromCreate=False)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from ObjectEntry:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
help(conn.getObjects)
# Out:
# Help on method getObjects in module omero.gateway:
#
# getObjects(obj_type, ids=None, params=None, attributes=None, respect_order=False, opts=None) method of omero.gateway._BlitzGateway instance
#     Retrieve Objects by type E.g. "Image"
#     Returns generator of appropriate :class:`BlitzObjectWrapper` type.
#     E.g. :class:`ImageWrapper`. If ids is None, all available objects will
#     be returned. i.e. listObjects() Filter objects by attributes. E.g.
#     attributes={'name':name}
#
#     :param obj_type:    Object type, e.g. "Project" see above
#     :type obj_type:     String
#     :param ids:         object IDs
#     :type ids:          List of Long
#     :param params:      omero.sys.Parameters, can be used for pagination,
#                         & filtering by owner. Takes precedence over opts.
#     :param attributes:  Dict of key-value pairs to filter results by.
#                         Key must be attribute of obj_type.
#                         E.g. 'name', 'ns'
# ...

# %%
def print_obj(obj, indent=0):
    """
    Helper method to display info about OMERO objects.
    Not all objects will have a "name" or owner field.
    """
    print("""%s%s:%s  Name:"%s" (owner=%s)""" % (
        " " * indent,
        obj.OMERO_CLASS,
        obj.getId(),
        obj.getName(),
        obj.getOwnerOmeName()))

# %%
def get_ObjectNameList(ClientObj, ObjName, options={}):
    return [obj.getName() for obj in ClientObj.getObjects(ObjName, opts=options)]

def if_object_exists(ClientObj, objType, objName, options={}):
    return objName in get_ObjectNameList(ClientObj, objType, options)

# %%
ProjectName = 'HiraiwaChemotaxis'

my_exp_id = conn.getUser().getId()

project_exists = if_object_exists(conn, 'Project', ProjectName, options={'owner': my_exp_id})

if project_exists:
    proj = conn.getObjects('Project', attributes={"name": ProjectName})
else:
    proj = conn.

# %%
help(conn.listProjects)
# Out:
# Help on method listProjects in module omero.gateway:
#
# listProjects(eid=None) method of omero.gateway._BlitzGateway instance
#     List every Project controlled by the security system.
#
#     :param eid:         Filters Projects by owner ID
#     :rtype:             :class:`ProjectWrapper` list

# %%
help(proj)
# Out:
# Help on generator object:
#
# getObjects = class generator(object)
#  |  Methods defined here:
#  |
#  |  __del__(...)
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  close(...)
#  |      close() -> raise GeneratorExit inside generator.
#  |
#  |  send(...)
#  |      send(arg) -> send 'arg' into generator,
#  |      return next yielded value or raise StopIteration.
#  |
#  |  throw(...)
#  |      throw(typ[,val[,tb]]) -> raise exception in generator,
#  |      return next yielded value or raise StopIteration.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  gi_code
#  |
#  |  gi_frame
#  |
#  |  gi_running
#  |
#  |  gi_yieldfrom
#  |      object being iterated by yield from, or None
